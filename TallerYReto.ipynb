# %% [markdown]
# <a href="https://colab.research.google.com/github/NSP2007/tareas-MatechoApli/blob/main/TallerYReto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Texto de título predeterminado
VelocidadInicial = 12 # @param {"type":"slider","min":0,"max":100,"step":1}
Angulo = 57 # @param {"type":"slider","min":0,"max":90,"step":1}
import numpy as np
import matplotlib.pyplot as plt

# Parámetros


# Conversión de ángulo a radianes
AnguloRad = np.radians(Angulo)

# Cálculo de las componentes de velocidad
vx = VelocidadInicial * np.cos(AnguloRad)
vy = VelocidadInicial * np.sin(AnguloRad)

# Cálculo del tiempo de vuelo
tiempoVuelo = (2 * vy) / 9.8

# Cálculo del alcance máximo y altura máxima
ymax = (vy**2) / (2 * 9.8)
xmax = vx * tiempoVuelo

# Generación de los puntos de la trayectoria
t = np.linspace(0, tiempoVuelo, num=100)
x = vx * t
y = vy * t - 0.5 * 9.8 * t**2  # Ecuación de movimiento vertical

# Gráfica
plt.plot(x, y, label="Trayectoria del proyectil")
plt.grid()
plt.xlabel('Distancia horizontal (m)')
plt.ylabel('Altura (m)')
plt.axhline(y=0, color='k', linestyle='--')
plt.axvline(x=0, color='k', linestyle='--')
plt.xlim(0, xmax + 1)
plt.ylim(0, ymax + 1)
plt.legend()
plt.title('Movimiento Parabólico')

# Mostrar la gráfica
plt.show()
