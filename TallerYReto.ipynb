# %% [markdown]
# <a href="https://colab.research.google.com/github/NSP2007/tareas-MatechoApli/blob/main/TallerYReto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#7

VelocidadInicial = 33 # @param {"type":"slider","min":0,"max":100,"step":1}
Angulo = 64 # @param {"type":"slider","min":0,"max":90,"step":1}
import numpy as np
import matplotlib.pyplot as plt

AnguloRad = np.radians(Angulo)

vx = VelocidadInicial * np.cos(AnguloRad)
vy = VelocidadInicial * np.sin(AnguloRad)

tiempoVuelo = (2 * vy) / 9.8

t = np.linspace(0, tiempoVuelo,100)
x = vx * t
y = vy * t - 0.5 * 9.8 * t**2

plt.plot(x, y)
plt.grid()
plt.xlabel("x")
plt.ylabel("y")
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.xlim(-1,50)
plt.ylim(-1,50)
plt.show()

# %%
#8
n = 2 # @param {"type":"slider","min":1,"max":10,"step":1}
import numpy as np
import matplotlib.pyplot as plt

def f(x):
  return x**n

x = np.linspace(0,1000,1000)
y = f(x)

plt.plot(x, y)
plt.grid()
plt.xlabel("x")
plt.ylabel("y")
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.xlim(-1,20)
plt.ylim(-1,500)
plt.show()

# %%
#EL MADAFAKIN RETO QUE NI ENTENDI

import numpy as np
import matplotlib.pyplot as plt
from numpy.random import random as rnd

n = 100000

coordenadasx = []
coordenadasy = []

inicio_x = 0.5
inicio_y = 0.65

puntos_de_x = []
puntos_de_y = []

puntos_de_x.append(inicio_x)
puntos_de_y.append(inicio_y)

numeros_de_x = 0
numeros_de_y = 0

veticex1 = 0
verticey1 = 0
verticex2 = 0.5
verticey2 = np.sqrt(3)/2
verticex3 = 1
verticey3 = 0

lista = []
lista = rnd(n)

for i in range(n):
  if (lista[i] <1/3):
    verticex = veticex1
    verticey = verticey1
  elif (1/3<lista[i]<2/3):
    verticex = verticex2
    verticey = verticey2
  elif (lista[i]>2/3):
    verticex = verticex3
    verticey = verticey3

  if (i==0):
    numeros_de_x = (verticex+numeros_de_x)/2
    numeros_de_y = (verticey+numeros_de_y)/2
  else:
    numeros_de_x = (verticex+numeros_de_x)/2
    numeros_de_y = (verticey+numeros_de_y)/2
  puntos_de_x.append(numeros_de_x)
  puntos_de_y.append(numeros_de_y)

plt.grid()
plt.xlabel("x")
plt.ylabel("y")
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.plot(puntos_de_x, puntos_de_y,".",ms = 0.25)
plt.show()
